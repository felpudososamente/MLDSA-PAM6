# %% [markdown]
# ### Importacion de las Librerías

# %%
import sys
from pathlib import Path
import sklearn
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import gradio as gr
from PIL import Image
import numpy as np
import os
import shutil

print("Python:", sys.version)
print("Pathlib: incluida en la stdlib")
print("scikit-learn:", sklearn.__version__)
print("TensorFlow:", tf.__version__)
print("Keras:", tf.keras.__version__)
print("Gradio:", gr.__version__)
print("Pillow:", Image.__version__)
print("NumPy:", np.__version__)
print("os: incluida en la stdlib")
print("shutil: incluida en la stdlib")
# Out:
# Python: 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]
# Pathlib: incluida en la stdlib
# scikit-learn: 1.8.0
# TensorFlow: 2.20.0
# Keras: 3.12.0
# Gradio: 6.1.0
# Pillow: 12.0.0
# NumPy: 2.3.5
# os: incluida en la stdlib
# shutil: incluida en la stdlib

# %% [markdown]
# ### Razas Etiquetadas en el Dataset

# %%
cat_breeds = [
    'Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair',
    'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue',
    'Siamese', 'Sphynx'
]

# %% [markdown]
# ### Clasificacion de las imágenes

# %%
images_path = Path("data/raw/images")
all_images = list(images_path.glob("*.jpg"))

print(f"Total de imágenes encontradas: {len(all_images)}")

cats = []
not_cats = []

for img_path in all_images:
    breed = "_".join(img_path.stem.split("_")[:-1])
    if breed in cat_breeds:
        cats.append(img_path)
    else:
        not_cats.append(img_path)

print(f"Gatos: {len(cats)}")
print(f"No gatos: {len(not_cats)}")
# Out:
# Total de imágenes encontradas: 7390
# Gatos: 2400
# No gatos: 4990

# %% [markdown]
# ### Particion de la data en entrenamiento y evaluación

# %%
cats_train, cats_val = train_test_split(cats, test_size=0.2, random_state=42)
not_cats_train, not_cats_val = train_test_split(not_cats, test_size=0.2, random_state=42)

# %% [markdown]
# ### Copiado de la data
# Copiamos las unidades de entrenamiento y evaluación en sus respectivas carpetas

# %%
def safe_copy_list_to_folder(file_list, dest_folder):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    else:
        # Vaciar carpeta para evitar duplicados
        for filename in os.listdir(dest_folder):
            file_path = os.path.join(dest_folder, filename)
            if os.path.isfile(file_path):
                os.remove(file_path)
    for f in file_list:
        shutil.copy(str(f), dest_folder)


print("Copiando imágenes...")

safe_copy_list_to_folder(cats_train, "data/processed/train/cat")
safe_copy_list_to_folder(cats_val, "data/processed/val/cat")
safe_copy_list_to_folder(not_cats_train, "data/processed/train/not_cat")
safe_copy_list_to_folder(not_cats_val, "data/processed/val/not_cat")

print("Copia completada.")
print(f"Train -> Gatos: {len(cats_train)}, No gatos: {len(not_cats_train)}")
print(f"Val   -> Gatos: {len(cats_val)}, No gatos: {len(not_cats_val)}")
# Out:
# Copiando imágenes...
# Copia completada.
# Train -> Gatos: 1920, No gatos: 3992
# Val   -> Gatos: 480, No gatos: 998

# %% [markdown]
# ### Carga, normalización y generación de imágenes

# %%
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 10

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    "data/processed/train",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    classes=["not_cat", "cat"]
)

val_generator = val_datagen.flow_from_directory(
    "data/processed/val",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    classes=["not_cat", "cat"]
)
# Out:
# Found 5912 images belonging to 2 classes.
# Found 1478 images belonging to 2 classes.

# %% [markdown]
# ### Modelo Tranfer Learning

# %%
def create_transfer_learning_model():
    base = tf.keras.applications.MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights="imagenet"
    )
    base.trainable = False

    model = models.Sequential([
        base,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])
    return model

model = create_transfer_learning_model()
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,259,265 (8.62 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ### Entrenamiento

# %%
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.2, patience=2)
    ]
)
# Out:
# Epoch 1/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 184s 968ms/step - accuracy: 0.9383 - loss: 0.1766 - val_accuracy: 0.9871 - val_loss: 0.0612 - learning_rate: 0.0010
# Epoch 2/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9755 - loss: 0.0749 - val_accuracy: 0.9892 - val_loss: 0.0413 - learning_rate: 0.0010
# Epoch 3/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 183s 989ms/step - accuracy: 0.9795 - loss: 0.0630 - val_accuracy: 0.9892 - val_loss: 0.0373 - learning_rate: 0.0010
# Epoch 4/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 184s 996ms/step - accuracy: 0.9819 - loss: 0.0561 - val_accuracy: 0.9912 - val_loss: 0.0318 - learning_rate: 0.0010
# Epoch 5/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9799 - loss: 0.0554 - val_accuracy: 0.9899 - val_loss: 0.0316 - learning_rate: 0.0010
# Epoch 6/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.9833 - loss: 0.0498 - val_accuracy: 0.9912 - val_loss: 0.0289 - learning_rate: 0.0010
# Epoch 7/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9838 - loss: 0.0455 - val_accuracy: 0.9919 - val_loss: 0.0277 - learning_rate: 0.0010
# Epoch 8/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 181s 979ms/step - accuracy: 0.9816 - loss: 0.0527 - val_accuracy: 0.9912 - val_loss: 0.0273 - learning_rate: 0.0010
# Epoch 9/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 182s 982ms/step - accuracy: 0.9826 - loss: 0.0471 - val_accuracy: 0.9912 - val_loss: 0.0293 - learning_rate: 0.0010
# Epoch 10/10
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.9831 - loss: 0.0453 - val_accuracy: 0.9912 - val_loss: 0.0269 - learning_rate: 0.0010

# %% [markdown]
# ### Guardado del modelo

# %%
model.save("model/cat_classifier.keras")
model.save("model/cat_classifier.h5")
model.export("model/cat_classifier_savedmodel")
print("Modelos guardados.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# INFO:tensorflow:Assets written to: model/cat_classifier_savedmodel\assets
# INFO:tensorflow:Assets written to: model/cat_classifier_savedmodel\assets
# Saved artifact at 'model/cat_classifier_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2697860643344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063008144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063009296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2697860642384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2697860643728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2697860643920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063009872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063010640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063010256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063009488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063009680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063011792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063011984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063008336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063008912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063012560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063014672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063014864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063013712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063013136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063011600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063016016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063016208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063015440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063012944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063015056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063013520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063014480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063015632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063017168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063016592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063016784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063016976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063015824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063018128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063017552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063017744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063017936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063013904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063019088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063019472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063019664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063018896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063019856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063016400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063018704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068657552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063019280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698063018512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068660240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068661392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068661968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068663312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068663120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068660624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068665040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068666192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068667152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068666768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068666960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068667536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068667920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068669072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068668496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068666384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068669648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068669840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068667344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068670992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068670416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068670608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068670800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068668304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068671952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068669264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068672144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068671568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068672336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068671760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089464848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089464272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698068671184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089463888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089465040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089465232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089464656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089466192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089465616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089465808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089466000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089464080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089467152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089466576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089466768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089466960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089464464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089468112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089467536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089467728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089467920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089465424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089469072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089468496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089468688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089468880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089466384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089470032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089469456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089469648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089469840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089467344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089470992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089470416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089470608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089470800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089468304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089471952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089471376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089471568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089471760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089469264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089472912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089472336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089472528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089472720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089470224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089473872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089473296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089473488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089473680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089471184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089474832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089474256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089474448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089474640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089472144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089475792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089475216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089475408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089475600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089473104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089476752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089476176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089476368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089476560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089474064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089477712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089477136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089477328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089477520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089475024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089478672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089478096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089478288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089478480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089475984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089479632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089479056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089476944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089479824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089479248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089480016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089479440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090332624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090333584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089477904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698089478864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090333392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090332432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090332240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090332816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090334544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090333968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090334160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090334352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090333200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090335504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090334928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090335120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090335312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090333008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090336464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090335888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090336080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090336272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090333776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090337424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090336848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090337040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090337232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090334736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090338384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090337808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090338000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090338192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090335696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090339344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090338768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090338960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090339152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090336656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090340304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090339728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090339920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090340112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090337616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090341264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090338576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2698090342416: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modelos guardados.

# %% [markdown]
# ### Interfaz Gráfica

# %%
model = tf.keras.models.load_model("model/cat_classifier.keras")

def predict_cat(image):
    img = image.resize((224, 224))
    arr = np.array(img) / 255.0
    arr = np.expand_dims(arr, axis=0)

    p = model.predict(arr)[0][0]

    if p > 0.5:
        return f" Es un GATO (Confianza: {p*100:.2f}%)"
    else:
        return f"NO es un gato (Confianza: {(1-p)*100:.2f}%)"

gr.Interface(
    fn=predict_cat,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="Clasificador de Gatos",
    description="Sube una imagen para identificar si contiene un gato."
).launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
